# %% [markdown]
# ## Astrohack - Pytorch Example
# <hr></hr>
#
# #### Morphological stellar mass of a galaxy
#
# The question we are interested in here is:<i>can we estimate the <i>M/L</i> using a single observation, at one wavelength?</i> Our dataset has images of the g-band (around 475 nm: blue). It is a supervised regression problem. Supervised, since the dataset actually has more observations and thus an accurate ground truth <i>M/L</i>. Regression, since the <i>M/L</i> is a continuous variable.
#
# #### <u> Getting started:</u>
# This notebook is should work with latest Pytorch 1.0,pandas,numpy. To run the notebooks, either jupyter notebook or jupyter lab is required. Care has to be taken to have the right CUDA toolkit version for Pytorch 1.0.

# %% [markdown]
# <ul>
#     <li><a>1. Setup</a>
#     <li><a>1.1 Download data:</a></li>
#     <li><a>1.2 Install dependencies </a></li>
#     <li><a>1.3 Import libraries </a></li>
#     </li></ul>
# <ul><li> <a>2. Prepare data </a></li></ul>
# <ul><li> <a>3. Define Convolution Neural Network </a></li>
#        <li><a>3.1 Define loss function:</a></li>
#     <li><a>3.2 Train network </a></li>
#    </ul>
#  <ul><li> <a>4. Evaluate the Network </a></li></ul>

# %% [markdown]
# ## 1. Setup
# ### 1.1 Download data:
# The AstroHack data files do not come along with this repository, you need to download them into the ./data directory before running this notebook.

# %% [markdown]
# ### 1.2 Install dependencies
# Run the following command to install dependencies

# %%
# !pip install -r requirement_pytorch.txt -q

# %% [markdown]
# ### 1.3 Import libraries
# Import necesseary libraries require to load, prepare our data and define our model.

# %%
import numpy as np
import pandas as pd
import os
import math

import PIL
from PIL import Image

import torch
from torch import *
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
import torch.nn as nn
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)

import pycuda.driver as cuda
cuda.init()
torch.cuda.current_device()
cuda.Device(0).name()
torch.cuda.set_device(0) 

import matplotlib.pyplot as plt

# %% [markdown]
# ##  2. Prepare data
#  <p> We need to prepare data before we train our model.</p>
# <p>Galaxies train,validation and evaluation dataset folder abosulute path is assignied to path variable and plotted before applying transformation and also plotted after applying transformation.</p>
# <p> Dataset and dataLoader for train and test set is created.</p>

# %%
"""
valid_dir : An absolute path for test images.
Train_dir : An absolute path for train images.
Eval_dir  : An absolute path for evaluation images.
"""
valid_dir =  "./data/valid_128pix/"
Train_dir ="./data/train_128pix/"
Eval_dir = "./data/evaluation_images_128pix/"

# %%
train_dataframe = pd.read_csv(Train_dir+"train_metadata.tsv",sep='\t')
valid_dataframe = pd.read_csv(valid_dir+"valid_metadata.tsv",sep='\t')
evaluation_dataframe = pd.read_csv(Eval_dir+"eval_metadata.tsv",sep='\t')

print("Train dataset shape: {} ".format(train_dataframe.shape))
print("Validation dataset shape: {} ".format(valid_dataframe.shape))
print("Evaluation dataset shape: {} ".format(evaluation_dataframe.shape))

train_dataframe.head(5)
# Out:
# Train dataset shape: (46384, 6)
# Validation dataset shape: (5154, 7)
# Evaluation dataset shape: (22089, 5)
#                SDSS_ID       M/L           L_g  distance_Mpc  galsize_kpc  \
# 0  1237665328772284501  3.104333  7.141540e+09    204.000005    27.124161
# 1  1237655107834871813  3.592175  9.341830e+10    191.999993    62.665323
# 2  1237661384381563217  1.347900  1.331889e+10    347.142858    41.137166
# 3  1237667252935721065  2.984367  5.575670e+10    354.857147    49.405998
# 4  1237658300598649239  0.539593  3.395893e+09    143.142853    18.599264
#
#                 image_name
# 0  1237665328772284501.png
# 1  1237655107834871813.png
# 2  1237661384381563217.png
# 3  1237667252935721065.png
# 4  1237658300598649239.png

# %% [markdown]
# Shown above are the top 3 rows in the training metadata files with columns:
# <ul>
#     <li>SDSS_ID: the unique identifier for each galaxy used by SDSS database.</li>
#     <li>M/L: the ground truth Mass-to-Luminosity ratio.</li>
#     <li>L_g: luminosity of the galaxy in g-band wavelength. Not used in this tutorial.</li>
#     <li>distance_Mpc: the distance between the subject galaxy and Earth in megaparsec. Not used in this tutorial.</li>
#     <li>galsize_kpc: the size of the subject galaxy in kiloparsec. Not used in this tutorial.</li>
#     <li>image_name: the filename of the corresponding image file.</li>
#     </ul>
# In this tutorial, we will use the image as the only feature to predict the M/L ratio.

# %%
"""
Plot galaxy images before applying transformation.

"""

_show_n_images = 4
fig, axs = plt.subplots(ncols=_show_n_images, figsize=(3 * _show_n_images, 3))
for i in range(_show_n_images):
    axs[i].imshow(Image.open(os.path.join(Train_dir,train_dataframe['image_name'].iloc[i])), cmap='gray')
    axs[i].set_title('{}\nM/L = {:.4f}'.format(train_dataframe['SDSS_ID'].iloc[i], 
                                               train_dataframe['M/L'].iloc[i]))

# %%
""" Transform object is list of transformation that every images should get through it.
    - Image get flipped horizontally.
    - RGB image get converted to greyscale.
    - Weights in image get normalised.
"""
transform = transforms.Compose([transforms.RandomHorizontalFlip(), \
                                transforms.Grayscale(),\
                                transforms.ToTensor() ,\
                                transforms.Normalize((0.5,), (0.5,)) \
                               ])

# %%
""" A class to load images of galaxies,its corresponding metadata and apply transformation to preprocess the images.
    GimageLoad : A dataset class, which is defined to load images and its corresponding mass-to-light value as label.
    
    Parameters : 
        dataFile : A metadata file, which consists of image name to load,corresponding M/L value and it should present in rootdir.
        rootdir  : A path variable, path should have of images to load and metadata file.
        transform : List of transformation to apply on image.
        
    Return : Returns image and it corresponding mass-to-light value.
"""
class GimageLoad(torch.utils.data.Dataset):
    def __init__(self,dataFile,rootdir,transform=None):
        self.imageName = pd.read_csv(os.path.join(rootdir,dataFile),usecols=['image_name'],sep='\t')
        self.label =  pd.read_csv(os.path.join(rootdir,dataFile),usecols=['M/L'],sep='\t')
        self.root_dir = rootdir
        self.transform = transform
    def __len__(self):
        return len(self.imageName)
    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.imageName.iloc[idx, 0])
        image = Image.open(img_name)
        
        image = self.transform(image)
        labels = self.label.iloc[idx, 0]

        return image,labels

# %%
"""
A dataset and dataloader object is created for train,test images.

    smimage_load_train : A dataset object for train set.
    simageTrainLoader  : A dataloader object for train set.
    
    smimage_load_test  : A dataset object for test set.
    simageTestLoader   : A dataloader object for test set.
    
"""
smimage_load_train = GimageLoad("train_metadata.tsv", Train_dir,transform)

simageTrainLoader = torch.utils.data.DataLoader(smimage_load_train,batch_size=16,shuffle=True,num_workers=10)

smimage_load_test = GimageLoad("valid_metadata.tsv", valid_dir,transform)

simageTestLoader = torch.utils.data.DataLoader(smimage_load_test,batch_size=16,shuffle=True,num_workers=10)

# %%
""" 
Plot images of galaxies transformed,scaled and processed through GimageLoad dataset and torch.utils dataloader.
"""
fig, axs = plt.subplots(ncols=_show_n_images, figsize=(3 * _show_n_images, 3))
for i,data in enumerate(torch.utils.data.DataLoader(smimage_load_test,batch_size=1,shuffle=True)):
    if i == _show_n_images:
        break
    axs[i].imshow(Image.fromarray(np.uint8(plt.cm.gist_earth(data[0][0][0].numpy())*255)), cmap='gray')
    axs[i].set_title('M/L = {:.4f}'.format(data[1].numpy()[0]))

# %% [markdown]
# # 3. Define  Convolutional Neural Network

# %% [markdown]
# As input, a CNN takes tensors of shape (image_height, image_width, color_channels). since here images are greyscale, number of channel is 1. Instantiated model is moved to GPU.

# %%
""" CNN , A class to define convolution neural network model.

    Parameter : CNN class is inherits all properties from nn.Module in pytorch library.
    
    Return    : A CNN instatiated model.
"""


class CNN(torch.nn.Module):

    def __init__(self):
        super(CNN, self).__init__()
        self.layer1 = torch.nn.Sequential(
            torch.nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2, stride=2),
            torch.nn.Dropout(0.5))
        self.layer2 = torch.nn.Sequential(
            torch.nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2, stride=2),
            torch.nn.Dropout(0.5))
        self.layer3 = torch.nn.Sequential(
            torch.nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2, stride=2, padding=1),
            torch.nn.Dropout(0.5))

        self.fc1 = torch.nn.Linear(36992, 625, bias=True)
        torch.nn.init.xavier_uniform(self.fc1.weight)
        self.layer4 = torch.nn.Sequential(
            self.fc1,
            torch.nn.ReLU(),
            torch.nn.Dropout(0.5))
        self.fc2 = torch.nn.Linear(625, 1, bias=True)
        torch.nn.init.xavier_uniform_(self.fc2.weight) # initialize parameters

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = out.view(out.size(0), -1)   # Flatten them for FC
        out = self.fc1(out)
        out = self.fc2(out)
        return out


# instantiate CNN model
simage_cnn = CNN()
simage_cnn.to(torch.device("cuda:0"))
# Out:
# /home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/ipykernel_launcher.py:30: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
# CNN(
#   (layer1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.5, inplace=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.5, inplace=False)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.5, inplace=False)
#   )
#   (fc1): Linear(in_features=36992, out_features=625, bias=True)
#   (layer4): Sequential(
#     (0): Linear(in_features=36992, out_features=625, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (fc2): Linear(in_features=625, out_features=1, bias=True)
# )

# %% [markdown]
# ### 3.1 Define a Loss function and optimizer
# ##### Loss function : SmoothL1Loss.
# It uses a squared term if the absolute error falls below 1 and an absolute term otherwise. It is less sensitive to outliers than the mean square error loss and in some cases prevents exploding gradients. In mean square error loss, we square the difference which results in a number which is much larger than the original number. These high values result in exploding gradients. This is avoided here as for numbers greater than 1, the numbers are not squared.

# %%
""" L1LossFlat ,a class to define loss, 
    Paramater : inherits all properties and function of smoothl1loss.
    
    Return :  A loss value.

"""
class L1LossFlat(nn.SmoothL1Loss):
    def forward(self, in1:torch.Tensor, target:torch.Tensor):
        return super().forward(in1.view(-1), target.view(-1))

# %% [markdown]
# ### 3.2 Train  network
#  We simply have to loop over our data iterator, and feed the inputs to the network and optimize.

# %%
import time

def trainNet(model, batch_size, n_epochs, learning_rate,checkpoint_path=os.getcwd()):
    
    #Print all of the hyperparameters of the training iteration:
    print("===== HYPERPARAMETERS =====")
    print("batch_size=", batch_size)
    print("epochs=", n_epochs)
    print("learning_rate=", learning_rate)
    print("=" * 30)
    
    min_val_loss = np.Inf
    epochs_no_improve = 0
    factor = 3 
    end_lr=1e-3
    
    model.train()
    #Get training data
    train_loader = simageTrainLoader
    n_batches = len(train_loader)
    
    #Create our loss and optimizer functions
    loss = L1LossFlat()
    
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
#     optimizer = torch.optim.SGD(model.parameters(), lr=1.)
    
    #Time for printing
    training_start_time = time.time()
    
    #Loop for n_epochs
    for epoch in range(n_epochs):
        
        running_loss = 0.0
        print_every = n_batches // 10
        start_time = time.time()
        total_train_loss = 0
        
        for i, data in enumerate(train_loader, 0):
            
            #Get inputs
            inputs, labels = data
            inputs = inputs.cuda()
            labels = labels.cuda()
            
            
            #Wrap them in a Variable object
            inputs, labels = Variable(inputs), Variable(labels)
            
            #Set the parameter gradients to zero
            optimizer.zero_grad()
            
            #Forward pass, backward pass, optimize
            outputs = model(inputs)
#             print(len(outputs))
            loss_size = loss(outputs, labels.float())
            loss_size.backward()
        
#             scheduler.step()
            
            optimizer.step()
#             print(loss_size.data)
            #Print statistics
            running_loss += loss_size.data
            total_train_loss += loss_size.data
            
            #Print every 10th batch of an epoch
            if (i + 1) % (print_every + 1) == 0:
                print("Epoch {}, {:d}% \t train_loss: {:.2f} took: {:.2f}s".format(
                        epoch+1, int(100 * (i+1) / n_batches), running_loss / print_every, time.time() - start_time))
                #Reset running loss and time
                running_loss = 0.0
                start_time = time.time()
            
        #At the end of the epoch, do a pass on the validation set
        total_val_loss = 0
        for inputs, labels in simageTestLoader:
            
            inputs = inputs.cuda()
            labels = labels.cuda()
            
            #Wrap tensors in Variables
            inputs, labels = Variable(inputs), Variable(labels)
            
            #Forward pass
            val_outputs = model(inputs)
            val_loss_size = loss(val_outputs, labels.float())
            total_val_loss += val_loss_size.data
    
        val_loss = total_val_loss / len(simageTestLoader)
        print(val_loss)
        if val_loss < min_val_loss:
              # Save the model
                torch.save(model, "checkpoint_path")
                epochs_no_improve = 0
                min_val_loss = val_loss
  
        else:
          epochs_no_improve += 1
          # Check early stopping condition
          if epochs_no_improve == n_epochs:
            print('Early stopping!')

            # Load in the best model
            model = torch.load(checkpoint_path)


        print("Validation loss = {:.2f}".format(total_val_loss / len(simageTestLoader)))
        
    print("Training finished, took {:.2f}s".format(time.time() - training_start_time))
    
    return model

# %%
simage_cnn = CNN()
simage_cnn.to(torch.device("cuda:0"))
# Out:
# /home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/ipykernel_launcher.py:30: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
# CNN(
#   (layer1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.5, inplace=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.5, inplace=False)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.5, inplace=False)
#   )
#   (fc1): Linear(in_features=36992, out_features=625, bias=True)
#   (layer4): Sequential(
#     (0): Linear(in_features=36992, out_features=625, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (fc2): Linear(in_features=625, out_features=1, bias=True)
# )

# %%
simage_cnn1 = trainNet(simage_cnn, batch_size=128, n_epochs=20, learning_rate=0.001)
# Out:
# ===== HYPERPARAMETERS =====
# batch_size= 128
# epochs= 20
# learning_rate= 0.001
# ==============================
# Epoch 1, 10% 	 train_loss: 0.77 took: 11.41s
# Epoch 1, 20% 	 train_loss: 0.61 took: 10.74s
# Epoch 1, 30% 	 train_loss: 0.60 took: 10.73s
# Epoch 1, 40% 	 train_loss: 0.61 took: 10.75s
# Epoch 1, 50% 	 train_loss: 0.62 took: 10.82s
# Epoch 1, 60% 	 train_loss: 0.60 took: 10.77s
# Epoch 1, 70% 	 train_loss: 0.62 took: 10.72s
# Epoch 1, 80% 	 train_loss: 0.59 took: 10.72s
# Epoch 1, 90% 	 train_loss: 0.59 took: 10.73s
# tensor(0.5832, device='cuda:0')
# /home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type CNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Validation loss = 0.58
# Epoch 2, 10% 	 train_loss: 0.58 took: 11.09s
# Epoch 2, 20% 	 train_loss: 0.56 took: 10.74s
# Epoch 2, 30% 	 train_loss: 0.58 took: 10.74s
# Epoch 2, 40% 	 train_loss: 0.56 took: 10.75s
# Epoch 2, 50% 	 train_loss: 0.56 took: 10.75s
# Epoch 2, 60% 	 train_loss: 0.55 took: 10.77s
# Epoch 2, 70% 	 train_loss: 0.59 took: 10.73s
# Epoch 2, 80% 	 train_loss: 0.54 took: 10.74s
# Epoch 2, 90% 	 train_loss: 0.55 took: 10.74s
# tensor(0.5466, device='cuda:0')
# Validation loss = 0.55
# Epoch 3, 10% 	 train_loss: 0.55 took: 11.27s
# Epoch 3, 20% 	 train_loss: 0.53 took: 10.79s
# Epoch 3, 30% 	 train_loss: 0.54 took: 10.76s
# Epoch 3, 40% 	 train_loss: 0.53 took: 10.77s
# Epoch 3, 50% 	 train_loss: 0.53 took: 10.75s
# Epoch 3, 60% 	 train_loss: 0.53 took: 10.77s
# Epoch 3, 70% 	 train_loss: 0.52 took: 10.77s
# Epoch 3, 80% 	 train_loss: 0.54 took: 10.75s
# Epoch 3, 90% 	 train_loss: 0.53 took: 10.74s
# tensor(0.5296, device='cuda:0')
# Validation loss = 0.53
# Epoch 4, 10% 	 train_loss: 0.52 took: 11.29s
# Epoch 4, 20% 	 train_loss: 0.53 took: 10.80s
# Epoch 4, 30% 	 train_loss: 0.53 took: 10.78s
# Epoch 4, 40% 	 train_loss: 0.52 took: 10.80s
# Epoch 4, 50% 	 train_loss: 0.53 took: 10.77s
# Epoch 4, 60% 	 train_loss: 0.50 took: 10.81s
# Epoch 4, 70% 	 train_loss: 0.53 took: 10.95s
# Epoch 4, 80% 	 train_loss: 0.55 took: 10.82s
# Epoch 4, 90% 	 train_loss: 0.50 took: 10.78s
# tensor(0.5153, device='cuda:0')
# Validation loss = 0.52
# Epoch 5, 10% 	 train_loss: 0.52 took: 11.17s
# Epoch 5, 20% 	 train_loss: 0.51 took: 10.76s
# Epoch 5, 30% 	 train_loss: 0.51 took: 10.76s
# Epoch 5, 40% 	 train_loss: 0.52 took: 10.77s
# Epoch 5, 50% 	 train_loss: 0.51 took: 10.74s
# Epoch 5, 60% 	 train_loss: 0.52 took: 10.76s
# Epoch 5, 70% 	 train_loss: 0.50 took: 10.74s
# Epoch 5, 80% 	 train_loss: 0.51 took: 10.79s
# Epoch 5, 90% 	 train_loss: 0.52 took: 10.73s
# tensor(0.5119, device='cuda:0')
# Validation loss = 0.51
# Epoch 6, 10% 	 train_loss: 0.52 took: 11.10s
# Epoch 6, 20% 	 train_loss: 0.50 took: 10.76s
# Epoch 6, 30% 	 train_loss: 0.51 took: 10.76s
# Epoch 6, 40% 	 train_loss: 0.51 took: 10.75s
# Epoch 6, 50% 	 train_loss: 0.51 took: 10.75s
# Epoch 6, 60% 	 train_loss: 0.51 took: 10.74s
# Epoch 6, 70% 	 train_loss: 0.50 took: 10.73s
# Epoch 6, 80% 	 train_loss: 0.51 took: 10.74s
# Epoch 6, 90% 	 train_loss: 0.51 took: 10.77s
# tensor(0.5113, device='cuda:0')
# Validation loss = 0.51
# Epoch 7, 10% 	 train_loss: 0.49 took: 11.10s
# Epoch 7, 20% 	 train_loss: 0.51 took: 10.76s
# Epoch 7, 30% 	 train_loss: 0.50 took: 10.74s
# Epoch 7, 40% 	 train_loss: 0.51 took: 10.79s
# Epoch 7, 50% 	 train_loss: 0.49 took: 10.74s
# Epoch 7, 60% 	 train_loss: 0.49 took: 10.78s
# Epoch 7, 70% 	 train_loss: 0.52 took: 10.74s
# Epoch 7, 80% 	 train_loss: 0.48 took: 10.76s
# Epoch 7, 90% 	 train_loss: 0.50 took: 10.84s
# tensor(0.5084, device='cuda:0')
# Validation loss = 0.51
# Epoch 8, 10% 	 train_loss: 0.50 took: 11.06s
# Epoch 8, 20% 	 train_loss: 0.50 took: 10.75s
# Epoch 8, 30% 	 train_loss: 0.51 took: 10.73s
# Epoch 8, 40% 	 train_loss: 0.51 took: 10.74s
# Epoch 8, 50% 	 train_loss: 0.50 took: 10.75s
# Epoch 8, 60% 	 train_loss: 0.50 took: 10.73s
# Epoch 8, 70% 	 train_loss: 0.48 took: 10.74s
# Epoch 8, 80% 	 train_loss: 0.49 took: 10.73s
# Epoch 8, 90% 	 train_loss: 0.49 took: 10.76s
# tensor(0.4947, device='cuda:0')
# Validation loss = 0.49
# Epoch 9, 10% 	 train_loss: 0.48 took: 11.10s
# Epoch 9, 20% 	 train_loss: 0.49 took: 10.79s
# Epoch 9, 30% 	 train_loss: 0.50 took: 10.74s
# Epoch 9, 40% 	 train_loss: 0.49 took: 10.78s
# Epoch 9, 50% 	 train_loss: 0.50 took: 10.76s
# Epoch 9, 60% 	 train_loss: 0.49 took: 10.75s
# Epoch 9, 70% 	 train_loss: 0.50 took: 10.76s
# Epoch 9, 80% 	 train_loss: 0.49 took: 10.77s
# Epoch 9, 90% 	 train_loss: 0.49 took: 10.72s
# tensor(0.4979, device='cuda:0')
# Validation loss = 0.50
# Epoch 10, 10% 	 train_loss: 0.50 took: 11.16s
# Epoch 10, 20% 	 train_loss: 0.49 took: 10.74s
# Epoch 10, 30% 	 train_loss: 0.48 took: 10.75s
# Epoch 10, 40% 	 train_loss: 0.49 took: 10.76s
# Epoch 10, 50% 	 train_loss: 0.48 took: 10.74s
# Epoch 10, 60% 	 train_loss: 0.49 took: 10.76s
# Epoch 10, 70% 	 train_loss: 0.49 took: 10.78s
# Epoch 10, 80% 	 train_loss: 0.51 took: 10.75s
# Epoch 10, 90% 	 train_loss: 0.50 took: 10.76s
# tensor(0.4902, device='cuda:0')
# Validation loss = 0.49
# Epoch 11, 10% 	 train_loss: 0.49 took: 11.20s
# Epoch 11, 20% 	 train_loss: 0.50 took: 10.77s
# Epoch 11, 30% 	 train_loss: 0.50 took: 10.76s
# Epoch 11, 40% 	 train_loss: 0.48 took: 10.76s
# Epoch 11, 50% 	 train_loss: 0.50 took: 10.74s
# Epoch 11, 60% 	 train_loss: 0.49 took: 10.76s
# Epoch 11, 70% 	 train_loss: 0.47 took: 10.78s
# Epoch 11, 80% 	 train_loss: 0.50 took: 10.81s
# Epoch 11, 90% 	 train_loss: 0.47 took: 10.75s
# tensor(0.5033, device='cuda:0')
# Validation loss = 0.50
# Epoch 12, 10% 	 train_loss: 0.48 took: 11.26s
# Epoch 12, 20% 	 train_loss: 0.49 took: 10.81s
# Epoch 12, 30% 	 train_loss: 0.49 took: 10.79s
# Epoch 12, 40% 	 train_loss: 0.47 took: 10.78s
# Epoch 12, 50% 	 train_loss: 0.48 took: 10.81s
# Epoch 12, 60% 	 train_loss: 0.48 took: 10.93s
# Epoch 12, 70% 	 train_loss: 0.50 took: 10.95s
# Epoch 12, 80% 	 train_loss: 0.48 took: 10.79s
# Epoch 12, 90% 	 train_loss: 0.50 took: 10.79s
# tensor(0.4936, device='cuda:0')
# Validation loss = 0.49
# Epoch 13, 10% 	 train_loss: 0.48 took: 11.09s
# Epoch 13, 20% 	 train_loss: 0.49 took: 10.77s
# Epoch 13, 30% 	 train_loss: 0.50 took: 10.76s
# Epoch 13, 40% 	 train_loss: 0.48 took: 10.75s
# Epoch 13, 50% 	 train_loss: 0.47 took: 10.73s
# Epoch 13, 60% 	 train_loss: 0.47 took: 10.77s
# Epoch 13, 70% 	 train_loss: 0.48 took: 10.74s
# Epoch 13, 80% 	 train_loss: 0.48 took: 10.77s
# Epoch 13, 90% 	 train_loss: 0.49 took: 10.72s
# tensor(0.4938, device='cuda:0')
# Validation loss = 0.49
# Epoch 14, 10% 	 train_loss: 0.48 took: 11.11s
# Epoch 14, 20% 	 train_loss: 0.48 took: 10.75s
# Epoch 14, 30% 	 train_loss: 0.46 took: 10.74s
# Epoch 14, 40% 	 train_loss: 0.48 took: 10.74s
# Epoch 14, 50% 	 train_loss: 0.47 took: 10.76s
# Epoch 14, 60% 	 train_loss: 0.48 took: 10.72s
# Epoch 14, 70% 	 train_loss: 0.49 took: 10.77s
# Epoch 14, 80% 	 train_loss: 0.47 took: 10.75s
# Epoch 14, 90% 	 train_loss: 0.50 took: 10.74s
# tensor(0.4874, device='cuda:0')
# Validation loss = 0.49
# Epoch 15, 10% 	 train_loss: 0.47 took: 11.07s
# Epoch 15, 20% 	 train_loss: 0.46 took: 10.75s
# Epoch 15, 30% 	 train_loss: 0.49 took: 10.76s
# Epoch 15, 40% 	 train_loss: 0.48 took: 10.76s
# Epoch 15, 50% 	 train_loss: 0.49 took: 10.79s
# Epoch 15, 60% 	 train_loss: 0.49 took: 10.73s
# Epoch 15, 70% 	 train_loss: 0.49 took: 10.73s
# Epoch 15, 80% 	 train_loss: 0.48 took: 10.77s
# Epoch 15, 90% 	 train_loss: 0.50 took: 10.75s
# tensor(0.4762, device='cuda:0')
# Validation loss = 0.48
# Epoch 16, 10% 	 train_loss: 0.47 took: 11.12s
# Epoch 16, 20% 	 train_loss: 0.47 took: 10.74s
# Epoch 16, 30% 	 train_loss: 0.48 took: 10.76s
# Epoch 16, 40% 	 train_loss: 0.47 took: 10.72s
# Epoch 16, 50% 	 train_loss: 0.49 took: 10.78s
# Epoch 16, 60% 	 train_loss: 0.48 took: 10.73s
# Epoch 16, 70% 	 train_loss: 0.48 took: 10.76s
# Epoch 16, 80% 	 train_loss: 0.47 took: 10.73s
# Epoch 16, 90% 	 train_loss: 0.47 took: 10.80s
# tensor(0.4801, device='cuda:0')
# Validation loss = 0.48
# Epoch 17, 10% 	 train_loss: 0.48 took: 11.13s
# Epoch 17, 20% 	 train_loss: 0.47 took: 10.76s
# Epoch 17, 30% 	 train_loss: 0.47 took: 10.74s
# Epoch 17, 40% 	 train_loss: 0.48 took: 10.80s
# Epoch 17, 50% 	 train_loss: 0.48 took: 10.78s
# Epoch 17, 60% 	 train_loss: 0.47 took: 10.76s
# Epoch 17, 70% 	 train_loss: 0.46 took: 10.78s
# Epoch 17, 80% 	 train_loss: 0.48 took: 10.80s
# Epoch 17, 90% 	 train_loss: 0.46 took: 10.75s
# tensor(0.4750, device='cuda:0')
# Validation loss = 0.47
# Epoch 18, 10% 	 train_loss: 0.48 took: 11.14s
# Epoch 18, 20% 	 train_loss: 0.48 took: 10.75s
# Epoch 18, 30% 	 train_loss: 0.49 took: 10.75s
# Epoch 18, 40% 	 train_loss: 0.49 took: 10.74s
# Epoch 18, 50% 	 train_loss: 0.46 took: 10.75s
# Epoch 18, 60% 	 train_loss: 0.49 took: 10.74s
# Epoch 18, 70% 	 train_loss: 0.45 took: 10.78s
# Epoch 18, 80% 	 train_loss: 0.48 took: 10.74s
# Epoch 18, 90% 	 train_loss: 0.47 took: 10.74s
# tensor(0.4769, device='cuda:0')
# Validation loss = 0.48
# Epoch 19, 10% 	 train_loss: 0.47 took: 11.10s
# Epoch 19, 20% 	 train_loss: 0.45 took: 10.76s
# Epoch 19, 30% 	 train_loss: 0.48 took: 10.75s
# Epoch 19, 40% 	 train_loss: 0.47 took: 10.78s
# Epoch 19, 50% 	 train_loss: 0.47 took: 10.73s
# Epoch 19, 60% 	 train_loss: 0.49 took: 10.77s
# Epoch 19, 70% 	 train_loss: 0.47 took: 10.74s
# Epoch 19, 80% 	 train_loss: 0.47 took: 10.76s
# Epoch 19, 90% 	 train_loss: 0.49 took: 10.75s
# tensor(0.4749, device='cuda:0')
# Validation loss = 0.47
# Epoch 20, 10% 	 train_loss: 0.46 took: 11.14s
# Epoch 20, 20% 	 train_loss: 0.47 took: 10.75s
# Epoch 20, 30% 	 train_loss: 0.46 took: 10.76s
# Epoch 20, 40% 	 train_loss: 0.47 took: 10.77s
# Epoch 20, 50% 	 train_loss: 0.47 took: 10.75s
# Epoch 20, 60% 	 train_loss: 0.48 took: 10.77s
# Epoch 20, 70% 	 train_loss: 0.47 took: 10.72s
# Epoch 20, 80% 	 train_loss: 0.48 took: 10.76s
# Epoch 20, 90% 	 train_loss: 0.49 took: 10.76s
# tensor(0.4719, device='cuda:0')
# Validation loss = 0.47
# Training finished, took 2255.64s

# %% [markdown]
# ## 4. Evaluate the network

# %%
smimage_load_test_pred = GimageLoad("eval_metadata2.tsv", Test_dir,transform)

simageTestLoader_test = torch.utils.data.DataLoader(smimage_load_test_pred,batch_size=1,shuffle=True)

torch.cuda.empty_cache()

val_pred_y = []
val_true_y = []
simage_cnn1.eval()
for inputs, labels in simageTestLoader_test:
            inputs = inputs.cuda()

            inputs = Variable(inputs.float())

            j = simage_cnn1(inputs)
            i_pred = float(j[0][0].cpu().detach().numpy())
            val_pred_y.append(i_pred)
            val_true_y.append(float(labels[0].numpy()))

# %%
torch.save(simage_cnn1,"smass_torch.pth")
# Out:
# /home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type CNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
from scipy.stats import gaussian_kde
import matplotlib.pyplot as plt

def estimate_density(x, y, **kwargs):
    xy = np.vstack([x, y])
    kde = gaussian_kde(xy, **kwargs)
    z = kde(xy)
    # Sort the points by density, so that the densest points are plotted last
    idx = z.argsort()
    return x[idx], y[idx], z[idx]

def rmse(yt, yp):
    return np.sqrt(np.mean(np.square(yt - yp)))

def r2(yt, yp):
    ybar = np.mean(yt)
    return 1 - (np.sum(np.square(yt - yp)) / np.sum(np.square(yt - ybar)))

def plot_truevspred():
    y = np.array(val_true_i)
    y_pred = np.array(val_pred_i)
    rmse_val = rmse(y, y_pred)
    r2_val = r2(y, y_pred)
    
    xc, yc, c = estimate_density(y, y_pred)
    plt.rcParams['axes.labelsize'] = 20
    plt.rcParams['font.size'] = 10
    plt.figure(figsize=(10, 7))
    plt.scatter(xc, yc, c=c, alpha=0.35)
    plt.xlabel('True M/L')
    plt.ylabel('Predicted M/L')
    plt.plot([0, 8], [0, 8], 'k-')
    ax = plt.gca()
    fontsize = 24
    plt.text(0.05, 0.92, f'RMSE = {rmse_val:.3f}', transform=ax.transAxes,
             fontsize=fontsize)
    plt.text(0.05, 0.83, f'$R^2$ = {r2_val:.3f}', transform=ax.transAxes,
             fontsize=fontsize)
    
plot_truevspred()
